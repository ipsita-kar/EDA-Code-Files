# %%
import pandas as pd
import numpy as np
data=pd.read_csv("C:\\Users\\Admin\\Downloads\\amazon_prime.csv")

# %%
data['imdb_score']=data['imdb_score'].fillna(data['imdb_score'].mean())

# %%
data.head(20)
# Out:
#           id                                             title   type  \
# 0    ts20945                                 The Three Stooges   SHOW
# 1    tm19248                                       The General  MOVIE
# 2    tm82253                       The Best Years of Our Lives  MOVIE
# 3    tm83884                                   His Girl Friday  MOVIE
# 4    tm56584                                 In a Lonely Place  MOVIE
# 5   tm160494                                        Stagecoach  MOVIE
# 6    tm87233                             It's a Wonderful Life  MOVIE
# 7    tm19424                                            Detour  MOVIE
# 8   tm116781                                    My Man Godfrey  MOVIE
# 9   tm112005                                         Marihuana  MOVIE
# 10   tm22806  Intolerance: Love's Struggle Throughout the Ages  MOVIE
# 11   tm88001                                      The Stranger  MOVIE
# ...

# %%
pivot=pd.pivot_table(data,index="type",values="imdb_score",aggfunc='mean')

# %%
print(pivot)
# Out:
#        imdb_score
# type
# MOVIE    5.820003
# SHOW     6.957621

# %%
df=pd.DataFrame(data)
new_data=df[data["genres"].str.contains("comedy")]

# %%
new_data.head()
# Out:
#          id                  title   type  \
# 0   ts20945      The Three Stooges   SHOW
# 1   tm19248            The General  MOVIE
# 3   tm83884        His Girl Friday  MOVIE
# 6   tm87233  It's a Wonderful Life  MOVIE
# 8  tm116781         My Man Godfrey  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 3  Hildy, the journalist former wife of newspaper...          1940
# 6  A holiday favourite for generations...  George...          1946
# 8  Fifth Avenue socialite Irene Bullock needs a "...          1936
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 3               NaN       92
# 6                PG      130
# 8               NaN       95
#
#                                               genres production_countries  \
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame called 'data' with a column 'genres' containing lists of genres
unique_genres = set()

for genre_list in data['genres']:
    unique_genres.update(genre_list)

print("Unique Genres:")
for genre in unique_genres:
    print(genre)
# Out:
# Unique Genres:
# i
# l
# ]
# u
# p
# '
# s
# e
# [
# c
# f
# n
# y
# d
# h
# w
# r
# o
# ,
# a
# t
#
# m

# %%
data=df[data["release_year"]>=2000]

# %%
data.head()
# Out:
#            id                       title   type  \
# 2217  ts20981                    Survivor   SHOW
# 2225  tm28243                    The Gift  MOVIE
# 2226  tm23114  O Brother, Where Art Thou?  MOVIE
# 2235  tm21856                   Cast Away  MOVIE
# 2236  tm18133                 Unbreakable  MOVIE
#
#                                             description  release_year  \
# 2217  A reality show contest where sixteen or more c...          2000
# 2225  Annie Wilson, young widow and mother of three,...          2000
# 2226  In the deep south during the 1930s, three esca...          2000
# 2235  Chuck Nolan, a top international manager for F...          2000
# 2236  An ordinary man makes an extraordinary discove...          2000
#
#      age_certification  runtime  \
# 2217             TV-PG       48
# 2225                 R      112
# 2226             PG-13      107
# 2235             PG-13      143
# 2236             PG-13      106
#
# ...

# %%
data = data[[len(genres) > 0 for genres in data['genres']]]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7147 entries, 2217 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    7147 non-null   object
#  1   title                 7147 non-null   object
#  2   type                  7147 non-null   object
#  3   description           7035 non-null   object
#  4   release_year          7147 non-null   int64
#  5   age_certification     2437 non-null   object
#  6   runtime               7147 non-null   int64
#  7   genres                7147 non-null   object
#  8   production_countries  7147 non-null   object
#  9   seasons               1227 non-null   float64
#  10  imdb_id               6570 non-null   object
#  11  imdb_score            7147 non-null   float64
#  12  imdb_votes            6238 non-null   float64
#  13  tmdb_popularity       6634 non-null   float64
# ...
